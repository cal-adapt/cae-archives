# %% [markdown]
# # Use Case Title

# %% [markdown]
# Abstract: a few sentences about the general purpose of notebook. Use bullets to give high level overview of analysis/functions the notebook will do
#
# This is a template notebook for Analytics Engine use cases. Some general style considerations:
# - Header text should be short and to the point - only a few words. Include further details in body text below header
# - Only one level 1 header per notebook (title up top)
# - Use level 2 headers for major sections, including step #
# - Subsections within a major section should use **bold** text - it is okay if this text is longer than a heading because it won't be included in an outline

# %% [markdown]
# ## Step 0: Setup

# %% [markdown]
# Import libraries needed

# %%
## Import libraries

# %% [markdown]
# ## Step 1: Select data

# %% [markdown]
# Retrieve the data needed for subsequent analyses

# %%
## app.select()

# %% [markdown]
# ## Step 2: Retrieve data

# %% [markdown]
# Retrieve data selected in previous step

# %%
## app.retrieve()

# %% [markdown]
# ## Step 3: Transform data

# %% [markdown]
# High level description of transformations (any needed background info)

# %% [markdown]
# **Transformation 1**

# %% [markdown]
# Description of transformation 1

# %%
## Code for transformation 1

# %% [markdown]
# **Transformation 2**

# %% [markdown]
# Description of transformation 2

# %%
## Code for transformation 2

# %% [markdown]
# ## Step 4: Visualize data

# %% [markdown]
# Plot description

# %%
## Plot code

# %% [markdown]
# ## Step 5: Export data

# %% [markdown]
# Export data in NetCDF/csv/GeoTIFF format

# %%
## app.export_as()
