# %% [markdown]
# # Using the Analytics Engine (AE) to reproduce annual consumption model
# This notebook is an early draft attempt to reproduce the workflow CEC's Demand Forecast Unit takes to generate weather and climate information for the annual consumption model. Here the existing workflow is replicated, but connecting with new data from California's Fifth Climate Change Assessment.
#
# To execute a given 'cell' of this notebook, place the cursor in the cell and press the 'play' icon, or simply press shift+enter together. Some cells will take longer to run, and you will see a [$\ast$] to the left of the cell while AE is still working.

# %% [markdown]
# ## Step 0: Setup
# First, we'll import any general python libraries required to run the notebook.

# %%
import numpy as np
import pandas as pd
import xarray as xr
import panel as pn
pn.extension()

# %% [markdown]
# Because this notebook is still in development, we need to install a development branch of the climakitae library instead of the default branch that is loaded into the AE hub.

# %%
# %%capture
# %load_ext autoreload
# !pip install -e git+https://github.com/cal-adapt/climakitae.git@utils#egg=climakitae
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_409/3649273000.py in <module>
#       1 import importlib
#       2 get_ipython().system('pip install -e git+https://github.com/cal-adapt/climakitae.git@utils#egg=climakitae')
# ----> 3 importlib.reload("climakitae")
#
# /srv/conda/envs/notebook/lib/python3.9/importlib/__init__.py in reload(module)
#     138     """
#     139     if not module or not isinstance(module, types.ModuleType):
# --> 140         raise TypeError("reload() argument must be a module")
#     141     try:
#     142         name = module.__spec__.name
#
# TypeError: reload() argument must be a module

# %% [markdown]
# Next, we'll import the python library [climakitae](https://github.com/cal-adapt/climakitae), our AE toolkit for climate data analysis, along with this specific functions from that library that we'll use in this notebook.

# %%
from climakitae.utils import get_closest_gridcell
from climakitae.selectors import Boundaries
from climakitae.derive_variables import compute_hdd_cdd
from climakitae.cluster import Cluster
import climakitae as ck
# Out:
# Obtaining climakitae from git+https://github.com/cal-adapt/climakitae.git@utils#egg=climakitae
#   Cloning https://github.com/cal-adapt/climakitae.git (to revision utils) to ./src/climakitae
#   Running command git clone -q https://github.com/cal-adapt/climakitae.git /home/jovyan/dfu_notebooks/dfu_notebook_1/src/climakitae
#   Running command git checkout -b utils --track origin/utils
#   Switched to a new branch 'utils'
#   Branch 'utils' set up to track remote branch 'utils' from 'origin'.
# Requirement already satisfied: cartopy in /srv/conda/envs/notebook/lib/python3.9/site-packages (from climakitae) (0.20.1)
# Requirement already satisfied: geopandas in /srv/conda/envs/notebook/lib/python3.9/site-packages (from climakitae) (0.10.2)
# Requirement already satisfied: geoviews in /srv/conda/envs/notebook/lib/python3.9/site-packages (from climakitae) (1.9.2)
# Requirement already satisfied: holoviews in /srv/conda/envs/notebook/lib/python3.9/site-packages (from climakitae) (1.14.6)
# Requirement already satisfied: hvplot in /srv/conda/envs/notebook/lib/python3.9/site-packages (from climakitae) (0.7.3)
# Requirement already satisfied: intake in /srv/conda/envs/notebook/lib/python3.9/site-packages (from climakitae) (0.6.4)
# Requirement already satisfied: intake-xarray in /srv/conda/envs/notebook/lib/python3.9/site-packages (from climakitae) (0.5.0)
# Collecting lmoments3
#   Using cached lmoments3-1.0.4.post1-py3-none-any.whl (17 kB)
# WARNING: Discarding https://files.pythonhosted.org/packages/b6/83/6649731d9b30b937d65dc7eee7aa017311aed58bee0628f07304bbe33d8b/lmoments3-1.0.4.post1-py3-none-any.whl#sha256=137194c637bde5c99afe943e25b8f542f871620768f662cadb17dc212113f426 (from https://pypi.org/simple/lmoments3/). Requested lmoments3 from https://files.pythonhosted.org/packages/b6/83/6649731d9b30b937d65dc7eee7aa017311aed58bee0628f07304bbe33d8b/lmoments3-1.0.4.post1-py3-none-any.whl#sha256=137194c637bde5c99afe943e25b8f542f871620768f662cadb17dc212113f426 (from climakitae) has different version in metadata: '1.0.4'
#   Using cached lmoments3-1.0.1-py3-none-any.whl
# Requirement already satisfied: matplotlib in /srv/conda/envs/notebook/lib/python3.9/site-packages (from climakitae) (3.4.3)
# Requirement already satisfied: metpy in /srv/conda/envs/notebook/lib/python3.9/site-packages (from climakitae) (1.1.0)
# Requirement already satisfied: numpy in /srv/conda/envs/notebook/lib/python3.9/site-packages (from climakitae) (1.21.2)
# Requirement already satisfied: pandas in /srv/conda/envs/notebook/lib/python3.9/site-packages (from climakitae) (1.3.4)
# Requirement already satisfied: panel in /srv/conda/envs/notebook/lib/python3.9/site-packages (from climakitae) (0.12.4)
# Requirement already satisfied: param in /srv/conda/envs/notebook/lib/python3.9/site-packages (from climakitae) (1.11.1)
# Requirement already satisfied: pyproj in /srv/conda/envs/notebook/lib/python3.9/site-packages (from climakitae) (3.2.1)
# Requirement already satisfied: rioxarray in /srv/conda/envs/notebook/lib/python3.9/site-packages (from climakitae) (0.7.1)
# Requirement already satisfied: s3fs in /srv/conda/envs/notebook/lib/python3.9/site-packages (from climakitae) (2021.10.1)
# Requirement already satisfied: scipy in /srv/conda/envs/notebook/lib/python3.9/site-packages (from climakitae) (1.7.1)
# Requirement already satisfied: shapely in /srv/conda/envs/notebook/lib/python3.9/site-packages (from climakitae) (1.7.1)
# Requirement already satisfied: xarray in /srv/conda/envs/notebook/lib/python3.9/site-packages (from climakitae) (0.19.0)
# Requirement already satisfied: pyshp>=2.1 in /srv/conda/envs/notebook/lib/python3.9/site-packages (from cartopy->climakitae) (2.1.3)
# Requirement already satisfied: python-dateutil>=2.7 in /srv/conda/envs/notebook/lib/python3.9/site-packages (from matplotlib->climakitae) (2.7.5)
# Requirement already satisfied: cycler>=0.10 in /srv/conda/envs/notebook/lib/python3.9/site-packages (from matplotlib->climakitae) (0.10.0)
# Requirement already satisfied: pillow>=6.2.0 in /srv/conda/envs/notebook/lib/python3.9/site-packages (from matplotlib->climakitae) (8.3.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /srv/conda/envs/notebook/lib/python3.9/site-packages (from matplotlib->climakitae) (1.3.2)
# Requirement already satisfied: pyparsing>=2.2.1 in /srv/conda/envs/notebook/lib/python3.9/site-packages (from matplotlib->climakitae) (2.4.7)
# Requirement already satisfied: six in /srv/conda/envs/notebook/lib/python3.9/site-packages (from cycler>=0.10->matplotlib->climakitae) (1.16.0)
# Requirement already satisfied: certifi in /srv/conda/envs/notebook/lib/python3.9/site-packages (from pyproj->climakitae) (2021.10.8)
# Requirement already satisfied: fiona>=1.8 in /srv/conda/envs/notebook/lib/python3.9/site-packages (from geopandas->climakitae) (1.8.20)
# Requirement already satisfied: attrs>=17 in /srv/conda/envs/notebook/lib/python3.9/site-packages (from fiona>=1.8->geopandas->climakitae) (21.2.0)
# Requirement already satisfied: click>=4.0 in /srv/conda/envs/notebook/lib/python3.9/site-packages (from fiona>=1.8->geopandas->climakitae) (7.1.2)
# Requirement already satisfied: cligj>=0.5 in /srv/conda/envs/notebook/lib/python3.9/site-packages (from fiona>=1.8->geopandas->climakitae) (0.7.2)
# Requirement already satisfied: click-plugins>=1.0 in /srv/conda/envs/notebook/lib/python3.9/site-packages (from fiona>=1.8->geopandas->climakitae) (1.1.1)
# Requirement already satisfied: munch in /srv/conda/envs/notebook/lib/python3.9/site-packages (from fiona>=1.8->geopandas->climakitae) (2.5.0)
# Requirement already satisfied: setuptools in /srv/conda/envs/notebook/lib/python3.9/site-packages (from fiona>=1.8->geopandas->climakitae) (58.2.0)
# Requirement already satisfied: pytz>=2017.3 in /srv/conda/envs/notebook/lib/python3.9/site-packages (from pandas->climakitae) (2021.3)
# Requirement already satisfied: bokeh<2.5,>=2.4.0 in /srv/conda/envs/notebook/lib/python3.9/site-packages (from geoviews->climakitae) (2.4.1)
# Requirement already satisfied: tornado>=5.1 in /srv/conda/envs/notebook/lib/python3.9/site-packages (from bokeh<2.5,>=2.4.0->geoviews->climakitae) (6.1)
# Requirement already satisfied: Jinja2>=2.9 in /srv/conda/envs/notebook/lib/python3.9/site-packages (from bokeh<2.5,>=2.4.0->geoviews->climakitae) (3.0.2)
# Requirement already satisfied: PyYAML>=3.10 in /srv/conda/envs/notebook/lib/python3.9/site-packages (from bokeh<2.5,>=2.4.0->geoviews->climakitae) (5.4.1)
# Requirement already satisfied: packaging>=16.8 in /srv/conda/envs/notebook/lib/python3.9/site-packages (from bokeh<2.5,>=2.4.0->geoviews->climakitae) (21.0)
# Requirement already satisfied: typing-extensions>=3.10.0 in /srv/conda/envs/notebook/lib/python3.9/site-packages (from bokeh<2.5,>=2.4.0->geoviews->climakitae) (3.10.0.2)
# Requirement already satisfied: pyviz-comms>=0.7.4 in /srv/conda/envs/notebook/lib/python3.9/site-packages (from holoviews->climakitae) (2.1.0)
# Requirement already satisfied: colorcet in /srv/conda/envs/notebook/lib/python3.9/site-packages (from holoviews->climakitae) (2.0.6)
# Requirement already satisfied: MarkupSafe>=2.0 in /srv/conda/envs/notebook/lib/python3.9/site-packages (from Jinja2>=2.9->bokeh<2.5,>=2.4.0->geoviews->climakitae) (2.0.1)
# Requirement already satisfied: markdown in /srv/conda/envs/notebook/lib/python3.9/site-packages (from panel->climakitae) (3.3.4)
# Requirement already satisfied: tqdm>=4.48.0 in /srv/conda/envs/notebook/lib/python3.9/site-packages (from panel->climakitae) (4.62.3)
# Requirement already satisfied: requests in /srv/conda/envs/notebook/lib/python3.9/site-packages (from panel->climakitae) (2.26.0)
# Requirement already satisfied: bleach in /srv/conda/envs/notebook/lib/python3.9/site-packages (from panel->climakitae) (4.1.0)
# Requirement already satisfied: pyct>=0.4.4 in /srv/conda/envs/notebook/lib/python3.9/site-packages (from panel->climakitae) (0.4.6)
# Requirement already satisfied: webencodings in /srv/conda/envs/notebook/lib/python3.9/site-packages (from bleach->panel->climakitae) (0.5.1)
# Requirement already satisfied: entrypoints in /srv/conda/envs/notebook/lib/python3.9/site-packages (from intake->climakitae) (0.3)
# Requirement already satisfied: dask in /srv/conda/envs/notebook/lib/python3.9/site-packages (from intake->climakitae) (2021.9.1)
# Requirement already satisfied: appdirs in /srv/conda/envs/notebook/lib/python3.9/site-packages (from intake->climakitae) (1.4.4)
# Requirement already satisfied: fsspec>=0.7.4 in /srv/conda/envs/notebook/lib/python3.9/site-packages (from intake->climakitae) (2021.10.1)
# Requirement already satisfied: cloudpickle>=1.1.1 in /srv/conda/envs/notebook/lib/python3.9/site-packages (from dask->intake->climakitae) (2.0.0)
# Requirement already satisfied: toolz>=0.8.2 in /srv/conda/envs/notebook/lib/python3.9/site-packages (from dask->intake->climakitae) (0.11.1)
# Requirement already satisfied: partd>=0.3.10 in /srv/conda/envs/notebook/lib/python3.9/site-packages (from dask->intake->climakitae) (1.2.0)
# Requirement already satisfied: locket in /srv/conda/envs/notebook/lib/python3.9/site-packages (from partd>=0.3.10->dask->intake->climakitae) (0.2.0)
# Requirement already satisfied: msgpack in /srv/conda/envs/notebook/lib/python3.9/site-packages (from intake-xarray->climakitae) (1.0.2)
# Requirement already satisfied: netcdf4 in /srv/conda/envs/notebook/lib/python3.9/site-packages (from intake-xarray->climakitae) (1.5.7)
# Requirement already satisfied: zarr in /srv/conda/envs/notebook/lib/python3.9/site-packages (from intake-xarray->climakitae) (2.10.1)
# Requirement already satisfied: pint>=0.10.1 in /srv/conda/envs/notebook/lib/python3.9/site-packages (from metpy->climakitae) (0.17)
# Requirement already satisfied: traitlets>=4.3.0 in /srv/conda/envs/notebook/lib/python3.9/site-packages (from metpy->climakitae) (5.1.0)
# Requirement already satisfied: pooch>=0.1 in /srv/conda/envs/notebook/lib/python3.9/site-packages (from metpy->climakitae) (1.5.2)
# Requirement already satisfied: cftime in /srv/conda/envs/notebook/lib/python3.9/site-packages (from netcdf4->intake-xarray->climakitae) (1.5.1)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /srv/conda/envs/notebook/lib/python3.9/site-packages (from requests->panel->climakitae) (2.0.0)
# Requirement already satisfied: idna<4,>=2.5 in /srv/conda/envs/notebook/lib/python3.9/site-packages (from requests->panel->climakitae) (3.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /srv/conda/envs/notebook/lib/python3.9/site-packages (from requests->panel->climakitae) (1.26.7)
# Requirement already satisfied: rasterio in /srv/conda/envs/notebook/lib/python3.9/site-packages (from rioxarray->climakitae) (1.2.10)
# Requirement already satisfied: snuggs>=1.4.1 in /srv/conda/envs/notebook/lib/python3.9/site-packages (from rasterio->rioxarray->climakitae) (1.4.7)
# Requirement already satisfied: affine in /srv/conda/envs/notebook/lib/python3.9/site-packages (from rasterio->rioxarray->climakitae) (2.3.0)
# Requirement already satisfied: aiobotocore~=1.4.1 in /srv/conda/envs/notebook/lib/python3.9/site-packages (from s3fs->climakitae) (1.4.1)
# Requirement already satisfied: aioitertools>=0.5.1 in /srv/conda/envs/notebook/lib/python3.9/site-packages (from aiobotocore~=1.4.1->s3fs->climakitae) (0.8.0)
# Requirement already satisfied: wrapt>=1.10.10 in /srv/conda/envs/notebook/lib/python3.9/site-packages (from aiobotocore~=1.4.1->s3fs->climakitae) (1.13.2)
# Requirement already satisfied: aiohttp>=3.3.1 in /srv/conda/envs/notebook/lib/python3.9/site-packages (from aiobotocore~=1.4.1->s3fs->climakitae) (3.7.4.post0)
# Requirement already satisfied: botocore<1.20.107,>=1.20.106 in /srv/conda/envs/notebook/lib/python3.9/site-packages (from aiobotocore~=1.4.1->s3fs->climakitae) (1.20.106)
# Requirement already satisfied: async-timeout<4.0,>=3.0 in /srv/conda/envs/notebook/lib/python3.9/site-packages (from aiohttp>=3.3.1->aiobotocore~=1.4.1->s3fs->climakitae) (3.0.1)
# Requirement already satisfied: yarl<2.0,>=1.0 in /srv/conda/envs/notebook/lib/python3.9/site-packages (from aiohttp>=3.3.1->aiobotocore~=1.4.1->s3fs->climakitae) (1.5.1)
# Requirement already satisfied: chardet<5.0,>=2.0 in /srv/conda/envs/notebook/lib/python3.9/site-packages (from aiohttp>=3.3.1->aiobotocore~=1.4.1->s3fs->climakitae) (4.0.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /srv/conda/envs/notebook/lib/python3.9/site-packages (from aiohttp>=3.3.1->aiobotocore~=1.4.1->s3fs->climakitae) (5.2.0)
# Requirement already satisfied: jmespath<1.0.0,>=0.7.1 in /srv/conda/envs/notebook/lib/python3.9/site-packages (from botocore<1.20.107,>=1.20.106->aiobotocore~=1.4.1->s3fs->climakitae) (0.10.0)
# Requirement already satisfied: asciitree in /srv/conda/envs/notebook/lib/python3.9/site-packages (from zarr->intake-xarray->climakitae) (0.3.3)
# Requirement already satisfied: fasteners in /srv/conda/envs/notebook/lib/python3.9/site-packages (from zarr->intake-xarray->climakitae) (0.16)
# Requirement already satisfied: numcodecs>=0.6.4 in /srv/conda/envs/notebook/lib/python3.9/site-packages (from zarr->intake-xarray->climakitae) (0.9.1)
# Installing collected packages: lmoments3, climakitae
#   Running setup.py develop for climakitae
# Successfully installed climakitae lmoments3-1.0.1
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_409/1273003461.py in <module>
#       1 get_ipython().system('pip install -e git+https://github.com/cal-adapt/climakitae.git@utils#egg=climakitae')
# ----> 2 from climakitae.utils import get_closest_gridcell
#       3 from climakitae.selectors import Boundaries
#       4 from climakitae.derive_variables import compute_hdd_cdd
#       5 from climakitae.cluster import Cluster
#
# ModuleNotFoundError: No module named 'climakitae'

# %% [markdown]
# Because we have two separate notebooks covering this same topic, we've put shared functions in a utils module, named `utils_notebook_1.py`. We'll import in the functions from that file next.

# %%
from utils_notebook_1 import *

# %% [markdown]
# Additionally, get set up to make the computing go faster by executing the following cell. It will likely take several minutes to spin up! Learn more about dask and see some common [troubleshooting tips on our FAQ page](https://analytics.cal-adapt.org/docs/faq/).

# %%
cluster = Cluster()
cluster.adapt(minimum=0, maximum=8)
client = cluster.get_client()
cluster

# %% [markdown]
# To use climakitae, load a new application:

# %%
app = ck.Application()

# %% [markdown]
# ## Step 1: Retrieve the data

# %% [markdown]
# ### 1a) Read in the data
# To allow for better reproducibility of this notebook, we have put all data and location selections into a csv file, which should be located in the same folder as this notebook. We'll read this into our notebook by using the climakitae helper function `app.retrieve_from_csv()`, providing the local filepath to the csv file as an argument to the function.

# %%
# %%time
data = app.retrieve_from_csv("hourly_data.csv")

# %% [markdown]
# ### 1b) Preview the data
# The function above returns an xarray Dataset object, with the three variables we want to load in-- air temperature, relative humidity, and dew point temperature-- as separate elements of a single python object. Since all the variables have the same spatial and temporal dimensions, they can be stored in the same object. To access an individual variable (for example, Air Temperature at 2m), you can simple type `data["Air Temperature at 2m"]` to get just data for that variable.<br><br>
# Understanding the dimensionality of this object is not a prerequisite to understanding the concepts in this notebook. However, if you'd like to learn more about this data type, [xarray's documentation](https://docs.xarray.dev/en/stable/generated/xarray.Dataset.html) gives an excellent description.<br>

# %%
data

# %% [markdown]
# ### 1c) Preview the data using app.select()
# This panel will display the data and location settings of the final row in the csv file fed to `app.retrieve_from_csv()`. We'll display it in the notebook to give you a better sense of the data, as well as the other data options in the Analytics Engine catalog. <br><br>Although we won't do this in this particular notebook, you can also use this panel to directly modify the data and location selections, and then read in the data afterward by calling `app.retrieve()`.

# %%
app.select()

# %% [markdown]
# ## Step 2: Get data from the closest grid cell to the weather station.
# As an example - to replicate the historical observations at Sacramento Executive Airport, grab the grid cell from the model nearest to the airport.

# %% [markdown]
# ### 2a) Read in a csv file of the station coordinates
# Make sure the filepath to the csv file matches the correct location on your computer. This file will be read into the notebook as a pandas DataFrame object.

# %%
stations_df = pd.read_csv("CEC_Forecast_Weather Stations_California.csv", index_col="STATION")
stations_df.head(5) # Display the first 5 rows

# %% [markdown]
# ### 2b) Grab the closest grid cell to the weather station
# To demonstrate this process, we'll use the Sacramento Executive Airport weather station.

# %%
station_name = "SACRAMENTO EXECUTIVE AIRPORT"
one_station = stations_df.loc[station_name]

# %% [markdown]
# Next, we need to convert the lat/lon coordinate pair to the model's projection coordinates. We can easily do this using the built in helper function in climakitae: `get_closest_gridcell`. For more information on this function, you can call `help(get_closest_gridcell)` or look in the climakitae.utils module for the actual code that performs the computation.

# %%
data_closest_gridcell = get_closest_gridcell(
    data=data,
    lat=one_station.LAT_Y,
    lon=one_station.LON_X, 
)

# %% [markdown]
# ### 2c) Load the data into memory
# This may take some time, because the data has to be loaded into memory and then subsetted to get the closest grid cell. All computations we've done before this step are actually computed in this step; before, we just see a preview of the data. **Because of this, we recommend running this notebook in the Analytics Engine's Jupyter Hub, which provides additional computational resources that greatly speed up this step.**

# %%
# %%time
data_closest_gridcell = app.load(data_closest_gridcell)

# %% [markdown]
# ### 2d) Output final data product as a csv file
# We'll drop all unneeded coordinates and convert our xarray Dataset to a pandas Dataframe, allowing us to easily output the final data product to a csv file. In the output table, the first column is the time in units of UTC, and the second column are the various global climate models (which can be filtered in excel or in python code in the notebook). The other columns are the variables selected at the beginning of the notebook.

# %%
data_closest_gridcell_df = data_closest_gridcell.isel(scenario=0).drop(
    ["x","y","landmask","lakemask","lat","lon","Lambert_Conformal","scenario"]
).to_dataframe()
data_closest_gridcell_df.head()

# %%
filename = "hourly_data_closest_gridcell_{0}.csv".format(station_name.replace(" ", "_")).lower()
data_closest_gridcell_df.to_csv(filename, index=True)

# %% [markdown]
# ## Step 3: Compute the median value of the grid cells in station's corresponding forecast zone
# As an alternative to a single point, we can instead consider weather conditions across an entire forecast zone. In this example we calculate the median of all conditions across the Sacramento Municipal Utility District.

# %% [markdown]
# ### 3a) Read in the shapefiles of the demand forecast zones
# We'll use this to find the demand forecast zone that contains the weather station, then find the overlapping grid cells over which to compute the median value. The geometries of each demand forecast zone is available in our data catalog. You can grab the data as a pandas DataFrame object using the code provided below, or subset by forecast zones easily in `app.select` in the location subsetting tab.

# %%
# %%time
dfzs_df = Boundaries()._ca_forecast_zones # Load geometries from catalog
dfzs_df.head() # Display the first few rows

# %% [markdown]
# ### 3b) Crop the data to the corresponding forecast zone
# We'll use [geopanda's `.contains` function](https://geopandas.org/en/stable/docs/reference/api/geopandas.GeoSeries.contains.html) to find the demand forecast zone where the weather station is located, and print the result. Then, we'll use [rioxarray](https://corteva.github.io/rioxarray/stable/rioxarray.html#rioxarray.raster_array.RasterArray.clip) to clip the data to the geometry that defines the forecast zone.

# %%
data_dfz = clip_data_to_dfz(
    gridded_data=data, 
    dfzs_df=dfzs_df, 
    station_lat=one_station.LAT_Y,
    station_lon=one_station.LON_X
)

# %% [markdown]
# ### 3c) Visualize both the Demand Forecast Zone and the weather station on the same map

# %% [markdown]
# For simplicity's sake, we'll show just one variable and only two weeks of data. In the outputted map, you can see that our data contains multiple simulation options as well, which you can toggle between in the map's dropdown.

# %%
# Used to add weather station as star to map 
point_df = pd.DataFrame({
    "longitude (degrees_east)":[one_station.LON_X],
    "latitude (degrees_north)":[one_station.LAT_Y],
    "weather station": station_name
})

# Grab subset of data and load into memory 
to_plot = data_dfz["Air Temperature at 2m"].isel(time = np.arange(0,13))
to_plot = app.load(to_plot)

# %%
app.view(to_plot) * point_df.hvplot.points(
    hover_cols = ["weather station"], 
    marker = "star", size = 300, color = "black"
)

# %% [markdown]
# ### 3d) Agreggate values across grid cells in the forecast zone
# **Chose your aggregation: median, mean, min, or max.** All can be easily computed by xarray with just one line of code, thanks to xarray. You could also write your own code to compute a weighted mean.

# %%
data_dfz_aggregated = gridded_data.median(dim=["x","y"])
#data_dfz_aggregated = gridded_data.mean(dim=["x","y"])
#data_dfz_aggregated = gridded_data.min(dim=["x","y"])
#data_dfz_aggregated = gridded_data.max(dim=["x","y"])

# %% [markdown]
# Finally, let's load this final data product into memory

# %%
# %%time
data_dfz_aggregated = app.load(data_dfz_aggregated)

# %% [markdown]
# ### 3e) Output final data product as a csv file
# We'll drop all unneeded coordinates and convert our xarray Dataset to a pandas Dataframe, allowing us to easily output the final data product to a csv file.

# %%
dfz_aggregated_df = data_dfz_aggregated.isel(scenario=0).drop(
    ["scenario","Lambert_Conformal"]).to_dataframe()
dfz_aggregated_df.head()

# %%
filename = "dfz_aggregated_{0}.csv".format(station_name.replace(" ", "_").lower())
dfz_aggregated_df.to_csv(filename, index=True)

# %% [markdown]
# ## Step 4: Compute heating degree days and cooling degree days
# Here, a heating degree day (HDD) is calculated by computing how many degrees Farenheit **colder** the daily temperature is from a standard temperature of 65 degrees Farenheit. A cooling degree day (CDD) is calulcated by computing how many degrees **warmer** the daily temperature is from the same standard temperature.

# %% [markdown]
# ### 4a) Decide which input data you want to use
# You can use the closest grid cell to the weather station, which we computed in step 3. Or, you can use the data agreggated over the demand forecast zone, which we computed in step 4. Just comment out whichever you don't want to use. We've chosen to show the analysis with the agreggated DFZ data, but if you want to use the closest grid cell data, just comment out the DFZ cells and uncomment out the closest grid cells.<br><br>Depending on the input data, we will also set a new variable defining the number of grid cells. This will of course be just 1 for the closest grid cell method; for the agreggated DFZ data, however, this value will change depending on the size of the DFZ. This information is used to compute the annual agreggate HDD and CDD in step 5c.

# %%
# CLOSEST GRID CELL 
# data_to_use = data_closest_gridcell
# num_grid_cells = 1

# AGGREGATED CELLS IN DFZ 
data_to_use = data_dfz_aggregated 
num_grid_cells = data_dfz.x.size * data_dfz.y.size # Number of grid cells within the demand forecast region

# %% [markdown]
# ### 4b) Compute HDD and CDD
# We'll use the climakitae helper function `compute_hdd_cdd` to perform the computation, which uses a default standard temperature of 65 degrees F. You can change this default using the function argument `standard_temp`. The function performs the following calculations:<br><br>
# **HDD = 65 - temperature<br>
# CDD = (-1)\*(65 - temperature)**<br><br>
# For HDD, we can just subtract the 2m temperature from 65 degrees Farenheight, then set any negative to 0. For CDD, we will do the same, but will then multiply by -1 to turn negative values to positive, then set negative values to 0. We need to multiply by -1 for CDD to avoid having all negative values; for example, on a day of 80F, CDD = 65 - 80 = -15, but the CDD value is +15. Multiplying -15 by -1 will give us the true value of 15.

# %%
#help(compute_hdd_cdd) # See information about the function

# %%
t2 = data_to_use["Air Temperature at 2m"]
hdd, cdd = compute_hdd_cdd(t2, standard_temp=65)

# %% [markdown]
# ### 4c) Aggregate annually to find HDD and CDD per year
# To do this, we will first group the data by year and compute a sum across space and time. Then, we will divide the annual aggregated data by the number of grid cells over which the sum was computed.

# %%
hdd_annual = compute_annual_aggreggate(
    data=hdd, 
    name="Annual Heating Degree Days (HDD)", 
    num_grid_cells=num_grid_cells
)
cdd_annual = compute_annual_aggreggate(
    data=cdd, 
    name="Annual Cooling Degree Days (CDD)", 
    num_grid_cells=num_grid_cells
)

# %% [markdown]
# ### 4d) Compute the multimodel mean, min, and max.
# We'll add these statistics to our main datasets, `hdd_annual` and `cdd_annual`, so they can be easily accessed for plotting.

# %%
hdd_annual, cdd_annual = compute_multimodel_stats(hdd_annual, cdd_annual)

# %% [markdown]
# ### 4e) Compute a trendline using the mean of all simulations
# We'll find the coefficients for a first degree (linear) polynomial using [numpy's `polyfit` function](https://numpy.org/doc/stable/reference/generated/numpy.polyfit.html). The returned coefficients (**m** and **b** in the code below) will allow us to compute the trendline using the linear polynomial y = mx + b, where **y** is the trendline and **x** is the years.

# %%
hdd_trendline = trendline(hdd_annual) 
cdd_trendline = trendline(cdd_annual)

# %% [markdown]
# ### 4f) Visualize the results
# Using the python package *hvplot*, we can easily make a line plot of the annual aggregated data. To do this, we'll plot the annual HDD, then add the trendline on top. The code to generate the plot is contained in a function `hdd_cdd_lineplot`.

# %%
hdd_cdd_lineplot(
    annual_data = hdd_annual, 
    trendline = hdd_trendline, 
    title = "Annual Aggregate Heating Degree Days"
)

# %%
hdd_cdd_lineplot(
    annual_data = cdd_annual, 
    trendline = cdd_trendline, 
    title = "Annual Aggregate Cooling Degree Days"
)

# %% [markdown]
# ### 4g) Output data as csv files
# We'll drop all unneeded coordinates and convert our xarray Dataset to a pandas Dataframe, allowing us to easily output the final data product to a csv file.

# %%
# Merge and simplify data 
hdd_cdd_combined = xr.merge([hdd_annual, cdd_annual]).drop(["Lambert_Conformal","scenario"])
hdd_cdd_combined = app.load(hdd_cdd_combined) 

# Convert to pandas dataframe 
hdd_cdd_df = hdd_cdd_combined.to_dataframe()
hdd_cdd_df.head()

# %%
filename = "annual_hdd_cdd_{0}.csv".format(station_name.replace(" ", "_").lower())
hdd_cdd_df.to_csv(filename, index=True)

# %% [markdown]
# ## Step 5: Close the compute cluster
# Lastly, when you are done, close your cluster resources to free them up for the next time you work.

# %%
client.close()
